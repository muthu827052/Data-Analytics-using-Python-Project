# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
employee={
    "Emp_":[101,102,103,104,105],
    "Name":["Arun","Priya","Rahul","Divya","Kumar"],
    "Department":["IT","HR","IT","Finance","HR"],
    "Salary":[50000,40000,50000,55000,42000],
    "Experience":[2,3,5,6,4]
           }
df=pd.DataFrame(employee)
print("Employee Dataset")
print(df)
print("\nAverage Salary")
print(df["Salary"].mean())
print("\nEmployees in HR")
print(df[df["Department"]=="HR"])
print("\nEnployees with experience>3")
print(df[df["Experience"]>3])
print("\nEmployee count by department")
print(df["Department"].value_counts())
# Out:
# Employee Dataset
#    Emp_   Name Department  Salary  Experience
# 0   101   Arun         IT   50000           2
# 1   102  Priya         HR   40000           3
# 2   103  Rahul         IT   50000           5
# 3   104  Divya    Finance   55000           6
# 4   105  Kumar         HR   42000           4
#
# Average Salary
# 47400.0
#
# Employees in HR
#    Emp_   Name Department  Salary  Experience
# 1   102  Priya         HR   40000           3
# 4   105  Kumar         HR   42000           4
#
# Enployees with experience>3
#    Emp_   Name Department  Salary  Experience
# 2   103  Rahul         IT   50000           5
# 3   104  Divya    Finance   55000           6
# 4   105  Kumar         HR   42000           4
#
# Employee count by department
# Department
# IT         2
# HR         2
# Finance    1
# Name: count, dtype: int64
