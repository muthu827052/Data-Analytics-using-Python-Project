# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/DAY_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
products = ["Laptop","Mobile","Tablet","Headphone","SmartWatch"]

sales = np.array([100,200,400,450,80])

print("Total Sales:",np.sum(sales))
print("Average Sales:",np.mean(sales))
print("Highest Sales:",np.max(sales))
print("Lowest Sales:",np.min(sales))
# Out:
# Total Sales: 1230
# Average Sales: 246.0
# Highest Sales: 450
# Lowest Sales: 80

# %%
#best-selling product
best_index = np.argmax(sales)
print("Best-selling product:",products[best_index])

#Product-Wise sales
print("\n Product Sales Report")
for i in range(len(products)):
  print(products[1],":",sales[i])
# Out:
# Best-selling product: Headphone
#
#  Product Sales Report
# Mobile : 100
# Mobile : 200
# Mobile : 400
# Mobile : 450
# Mobile : 80

# %%
import numpy as np
products = ["Laptop","Mobile","Tablet","Headphone"]
sales = np.array([120,250,50,150])
print("Total Sales",np.sum(sales))

print("Average Sales",np.mean(sales))

print("Highest Sales",np.max(sales))

print("Lowest Sales",np.min(sales))

best_index = np.argmax(sales)
print("Best Selling Product",products[best_index])

print("\nProducts Sales Report")
for i in range(len(products)):
    print(f"{products[i]}:{sales[i]}")
# Out:
# Total Sales 570
# Average Sales 142.5
# Highest Sales 250
# Lowest Sales 50
# Best Selling Product Mobile
#
# Products Sales Report
# Laptop:120
# Mobile:250
# Tablet:50
# Headphone:150
