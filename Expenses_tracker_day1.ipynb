# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Expenses_tracker_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Expenses = [101, 270, 480,150]

Total = sum (Expenses)

print("Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [101, 270, 480, 150]
# Total Expenses: 1001
