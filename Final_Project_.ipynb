# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Final_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. E-Commerce Sales Performance Analysis

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

data ={
    "Sale_ID":[1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020],
    "Date":["2026-05-01","2026-05-02","2026-05-03","2026-05-04","2026-05-05","2026-05-06","2026-05-07","2026-05-08","2026-05-09","2026-05-10","2026-05-11","2026-05-12","2026-05-13","2026-05-14","2026-05-15","2026-05-16","2026-05-17","2026-05-18","2026-05-19","2026-05-20"],
    "Product":["Smartwatch","Laptop","Smartphone","Headphones","Camera","Smartwatch","Laptop","Smartphone","Headphones","Camera","Smartwatch","Laptop","Smartphone","Headphones","Camera","Smartwatch","Laptop","Smartphone","Headphones","Camera"],
    "Category":["Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics","Electronics"],
    "Quantity":[1,2,1,3,1,2,1,2,1,3,1,2,1,2,1,3,1,2,1,2],
    "Unit_Price":[250.00,1200.00,700.00,150.00,500.00,250.00,1200.00,700.00,150.00,500.00,250.00,1200.00,700.00,150.00,500.00,250.00,1200.00,700.00,150.00,500.00],
    "Total_Amount":[250.00,2400.00,700.00,450.00,500.00,500.00,1200.00,1400.00,150.00,1500.00,250.00,2400.00,700.00,300.00,500.00,750.00,1200.00,1400.00,150.00,1000.00],
    "Region":["North","South","East","West","North","South","East","West","North","South","East","West","North","South","East","West","North","South","East","West"],
    "Payment_Method":["Credit Card","PayPal","Debit Card","Credit Card","PayPal","Debit Card","Credit Card","PayPal","Debit Card","Credit Card","PayPal","Debit Card","Credit Card","PayPal","Debit Card","Credit Card","PayPal","Debit Card","Credit Card","PayPal"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Electronics         1       250.0
# 1      1002  2026-05-02      Laptop  Electronics         2      1200.0
# 2      1003  2026-05-03  Smartphone  Electronics         1       700.0
# 3      1004  2026-05-04  Headphones  Electronics         3       150.0
# 4      1005  2026-05-05      Camera  Electronics         1       500.0
# 5      1006  2026-05-06  Smartwatch  Electronics         2       250.0
# 6      1007  2026-05-07      Laptop  Electronics         1      1200.0
# 7      1008  2026-05-08  Smartphone  Electronics         2       700.0
# 8      1009  2026-05-09  Headphones  Electronics         1       150.0
# 9      1010  2026-05-10      Camera  Electronics         3       500.0
# 10     1011  2026-05-11  Smartwatch  Electronics         1       250.0
# 11     1012  2026-05-12      Laptop  Electronics         2      1200.0
# ...

# %%
df.head(20)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Electronics         1       250.0
# 1      1002  2026-05-02      Laptop  Electronics         2      1200.0
# 2      1003  2026-05-03  Smartphone  Electronics         1       700.0
# 3      1004  2026-05-04  Headphones  Electronics         3       150.0
# 4      1005  2026-05-05      Camera  Electronics         1       500.0
# 5      1006  2026-05-06  Smartwatch  Electronics         2       250.0
# 6      1007  2026-05-07      Laptop  Electronics         1      1200.0
# 7      1008  2026-05-08  Smartphone  Electronics         2       700.0
# 8      1009  2026-05-09  Headphones  Electronics         1       150.0
# 9      1010  2026-05-10      Camera  Electronics         3       500.0
# 10     1011  2026-05-11  Smartwatch  Electronics         1       250.0
# 11     1012  2026-05-12      Laptop  Electronics         2      1200.0
# ...

# %%
print(df.shape)
# Out:
# (20, 9)

# %%
print(df.isnull().sum())
# Out:
# Sale_ID           0
# Date              0
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Amount      0
# Region            0
# Payment_Method    0
# dtype: int64

# %%
df = df.drop_duplicates()

print(df)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Electronics         1       250.0
# 1      1002  2026-05-02      Laptop  Electronics         2      1200.0
# 2      1003  2026-05-03  Smartphone  Electronics         1       700.0
# 3      1004  2026-05-04  Headphones  Electronics         3       150.0
# 4      1005  2026-05-05      Camera  Electronics         1       500.0
# 5      1006  2026-05-06  Smartwatch  Electronics         2       250.0
# 6      1007  2026-05-07      Laptop  Electronics         1      1200.0
# 7      1008  2026-05-08  Smartphone  Electronics         2       700.0
# 8      1009  2026-05-09  Headphones  Electronics         1       150.0
# 9      1010  2026-05-10      Camera  Electronics         3       500.0
# 10     1011  2026-05-11  Smartwatch  Electronics         1       250.0
# 11     1012  2026-05-12      Laptop  Electronics         2      1200.0
# ...

# %%
total_sales = df["Total_Amount"].sum()
print("Total Sales:" ,total_sales)
# Out:
# Total Sales: 17700.0

# %%
product_sales = df.groupby("Product")["Total_Amount"].sum()

print(product_sales)
# Out:
# Product
# Camera        3500.0
# Headphones    1050.0
# Laptop        7200.0
# Smartphone    4200.0
# Smartwatch    1750.0
# Name: Total_Amount, dtype: float64

# %%
import matplotlib.pyplot as plt

# Line Chart

plt.plot(product, sale_ID,
         marker = "o",
        linestyle = "--",
        color = "green")

plt.title("Product Sales Analysis (Line Chart)")
plt.xlabel("Products")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Bar Chart
plt.bar(product, sale_ID,
        color = ("green","blue","yellow","pink","red"))

plt.title("Product Sales Analysis (Bar Chart)")
plt.xlabel("Products")
plt.ylabel("Sales")

plt.show()
