# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# E-Commerce Sales Analysis

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Sale_ID": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020],
    "Date": ["2023-01-01", "2023-01-01", "2023-01-02", "2023-01-02", "2023-01-03","2023-01-03", "2023-01-04", "2023-01-04", "2023-01-05", "2023-01-05","2023-01-06", "2023-01-06", "2023-01-07", "2023-01-07", "2023-01-08","2023-01-08", "2023-01-09", "2023-01-09", "2023-01-10", "2023-01-10"],
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Webcam","Headphones", "Speaker", "Router", "Printer", "External HDD","Laptop", "Mouse", "Keyboard", "Monitor", "Webcam","Headphones", "Speaker", "Router", "Printer", "External HDD"],
    "Category": ["Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics","Electronics", "Electronics", "Electronics", "Electronics", "Electronics","Electronics", "Electronics", "Electronics", "Electronics", "Electronics"],
    "Quantity": [1, 2, 1, 1, 3, 2, 1, 1, 1, 2, 1, 2, 1, 1, 3, 2, 1, 1, 1, 2 ],
    "Unit_Price": [1200.00, 25.00, 75.00, 300.00, 50.00,150.00, 100.00, 80.00, 200.00, 90.00,1200.00, 25.00, 75.00, 300.00, 50.00,150.00, 100.00, 80.00, 200.00, 90.00],
    "Total_Amount": [1200.00, 50.00, 75.00, 300.00, 150.00,300.00, 100.00, 80.00, 200.00, 180.00,1200.00, 50.00, 75.00, 300.00, 150.00,300.00, 100.00, 80.00, 200.00, 180.00 ],
    "Region": ["East", "West", "North", "South", "East","West", "North", "South", "East", "West","North", "South", "East", "West", "North","South", "East", "West", "North", "South"],
    "Payment_Method": ["Credit Card", "PayPal", "Credit Card", "Debit Card", "PayPal","Credit Card", "Debit Card", "PayPal", "Credit Card", "Debit Card","Credit Card", "PayPal", "Credit Card", "Debit Card", "PayPal","Credit Card", "Debit Card", "PayPal", "Credit Card", "Debit Card" ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Sale_ID        Date       Product     Category  Quantity  Unit_Price  \
# 0      1001  2023-01-01        Laptop  Electronics         1      1200.0
# 1      1002  2023-01-01         Mouse  Electronics         2        25.0
# 2      1003  2023-01-02      Keyboard  Electronics         1        75.0
# 3      1004  2023-01-02       Monitor  Electronics         1       300.0
# 4      1005  2023-01-03        Webcam  Electronics         3        50.0
# 5      1006  2023-01-03    Headphones  Electronics         2       150.0
# 6      1007  2023-01-04       Speaker  Electronics         1       100.0
# 7      1008  2023-01-04        Router  Electronics         1        80.0
# 8      1009  2023-01-05       Printer  Electronics         1       200.0
# 9      1010  2023-01-05  External HDD  Electronics         2        90.0
# 10     1011  2023-01-06        Laptop  Electronics         1      1200.0
# 11     1012  2023-01-06         Mouse  Electronics         2        25.0
# ...

# %%
df.head(20)
# Out:
#     Sale_ID        Date       Product     Category  Quantity  Unit_Price  \
# 0      1001  2023-01-01        Laptop  Electronics         1      1200.0
# 1      1002  2023-01-01         Mouse  Electronics         2        25.0
# 2      1003  2023-01-02      Keyboard  Electronics         1        75.0
# 3      1004  2023-01-02       Monitor  Electronics         1       300.0
# 4      1005  2023-01-03        Webcam  Electronics         3        50.0
# 5      1006  2023-01-03    Headphones  Electronics         2       150.0
# 6      1007  2023-01-04       Speaker  Electronics         1       100.0
# 7      1008  2023-01-04        Router  Electronics         1        80.0
# 8      1009  2023-01-05       Printer  Electronics         1       200.0
# 9      1010  2023-01-05  External HDD  Electronics         2        90.0
# 10     1011  2023-01-06        Laptop  Electronics         1      1200.0
# 11     1012  2023-01-06         Mouse  Electronics         2        25.0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sale_ID         20 non-null     int64
#  1   Date            20 non-null     object
#  2   Product         20 non-null     object
#  3   Category        20 non-null     object
#  4   Quantity        20 non-null     int64
#  5   Unit_Price      20 non-null     float64
#  6   Total_Amount    20 non-null     float64
#  7   Region          20 non-null     object
#  8   Payment_Method  20 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.5+ KB
# None

# %%
print(df.shape)
# Out:
# (20, 9)

# %%
print(df.isnull().sum())
# Out:
# Sale_ID           0
# Date              0
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Amount      0
# Region            0
# Payment_Method    0
# dtype: int64

# %%
df = df.drop_duplicates()

print(df)
# Out:
#     Sale_ID        Date       Product     Category  Quantity  Unit_Price  \
# 0      1001  2023-01-01        Laptop  Electronics         1      1200.0
# 1      1002  2023-01-01         Mouse  Electronics         2        25.0
# 2      1003  2023-01-02      Keyboard  Electronics         1        75.0
# 3      1004  2023-01-02       Monitor  Electronics         1       300.0
# 4      1005  2023-01-03        Webcam  Electronics         3        50.0
# 5      1006  2023-01-03    Headphones  Electronics         2       150.0
# 6      1007  2023-01-04       Speaker  Electronics         1       100.0
# 7      1008  2023-01-04        Router  Electronics         1        80.0
# 8      1009  2023-01-05       Printer  Electronics         1       200.0
# 9      1010  2023-01-05  External HDD  Electronics         2        90.0
# 10     1011  2023-01-06        Laptop  Electronics         1      1200.0
# 11     1012  2023-01-06         Mouse  Electronics         2        25.0
# ...

# %%
total_sales = df['Total_Amount'].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 5270.0

# %%
product_sales = df.groupby("Product")["Total_Amount"].sum()

print(product_sales)
# Out:
# Product
# External HDD     360.0
# Headphones       600.0
# Keyboard         150.0
# Laptop          2400.0
# Monitor          600.0
# Mouse            100.0
# Printer          400.0
# Router           160.0
# Speaker          200.0
# Webcam           300.0
# Name: Total_Amount, dtype: float64

# %%
product_sales.plot(kind="bar")

plt.title ("Product Sales Analysis")


plt.xlabel("Product")

plt.ylabel("Sales ")

plt.show()
