# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([90,65,32,14,75])

print(marks[1:3])
# Out:
# [65 32]

# %%
import numpy as np

arr = np.array([1,2,3,4,5,6])

new_arr = arr.reshape(2,3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
try:
    avg = float(input("Enter average marks: "))
    if avg >= 75:
        print("Grade: A")
    elif avg >= 60:
        print("Grade: B")
    elif avg >= 50:
        print("Grade: C")
    else:
       print("Grade: F")
except  ValueError:
                print("Please enter invalid numbers")
# Out:
# Enter average marks: 77
# Grade: A

# %%
scores=[80,90,78,95,88]

total=sum(scores)
average=total/len(scores)
highest=max(scores)
lowest=min(scores)

print("Total Score:",total)
print("Average Score:",average)
print("Highest Score:",highest)
print("Lowest Score:",lowest)
# Out:
# Total Score: 431
# Average Score: 86.2
# Highest Score: 95
# Lowest Score: 78

# %%
import numpy as np

marks = np.array([70,88,98,60])

average = np.mean(marks)

print(average)
# Out:
# 79.0

# %%
import numpy as np
salary=np.array([10000,20000,30000,40000,50000])
med=np.median(salary)
print(med)
# Out:
# 30000.0
