# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def attendance(attended, total):
  return (attended / total) * 100

attended = int(input("Classes Attended: "))
total = int(input("Total Classes: "))

percent = attendance(attended, total)

print ("Attendance Percentage =", round(percent, 2), "%")
# Out:
# Classes Attended: 66
# Total Classes: 55
# Attendance Percentage = 120.0 %
