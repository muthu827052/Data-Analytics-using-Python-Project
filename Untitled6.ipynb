# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
products = ["Laptop","Mobile","Headphone","Smartmatch"]

#Sales units
sales=np.array([120,250,80,150,100])

#Total sales
print("TotalSales:", np.sum(sales))

#Average sales
print("Average Sales:", np.mean(sales))
# Out:
# TotalSales: 700
# Average Sales: 140.0
