# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu827052/Data-Analytics-using-Python-Project/blob/main/Simple_Function_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship Students")
greet()
# Out:
# Hi Internship Students

# %%
def greet(name):
  print("Welcome", name)
greet("Harini")
# Out:
# Welcome Harini

# %%
def add(a, b):
  return a+b

result = add (10,40)
print("Sum=",result)
# Out:
# Sum= 50
